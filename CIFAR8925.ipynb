# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Hamahmi/CIFAR-10/blob/master/CIFAR8925.ipynb)

# %%
import numpy             as np
import matplotlib.pyplot as plt

# %matplotlib inline

from keras                     import regularizers
from keras.models              import Sequential
from keras.layers              import Dense
from keras.layers              import Dropout
from keras.layers              import Conv2D
from keras.layers              import Activation
from keras.layers              import MaxPooling2D
from keras.layers              import Flatten
from keras.layers              import BatchNormalization
from keras.datasets            import cifar10
from keras.callbacks           import ReduceLROnPlateau
from keras.optimizers          import RMSprop
from matplotlib.pyplot         import imshow
from keras.utils.np_utils      import to_categorical
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator


print("\nImporting ✓\n")


(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print("\nLoading ✓\n")


def check(x):
    if x >= 0.8400:
      return "\nPass ✓✓✓\n"
    return "\nFail ✗✗✗\n"
  
  
  
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train = x_train.reshape(-1, 32, 32, 3) / 255 
x_test  =  x_test.reshape(-1, 32, 32, 3) / 255
print(x_train.shape)

y_train = to_categorical(y_train,10)
y_test  = to_categorical(y_test ,10)
print(y_train.shape)


print("\nReshaping ✓\n")



model = Sequential()

model.add(Conv2D(128, padding='same', kernel_size=(5, 5), activation='relu', input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(Conv2D(128, padding='same', kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(256, padding='same', kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, padding='same', kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(256, padding='same', kernel_size=(5, 5), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, padding='same', kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))



model.add(Flatten())


model.add(Dense(256, activation = "relu"))
model.add(Dropout(0.3))
model.add(Dense(10, activation = "softmax"))



optimizer = RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0)
compiled_model = model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

print("\nCompiling ✓\n")



# learning rate annealer
learning_rate_reduction = ReduceLROnPlateau( monitor='val_acc', patience=3, verbose=1, factor=0.5, min_lr=0.00001)




datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

datagen.fit(x_train)



print("Done1")
# Out:
# Using TensorFlow backend.
# Importing ✓
#
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 14s 0us/step
#
# Loading ✓
#
# (50000, 32, 32, 3)
# (50000, 10)
#
# Reshaping ✓
#
#
# Compiling ✓
#
# Done1

# %%
fitting_model = model.fit_generator( datagen.flow(x_train,y_train, batch_size=128), epochs = 64,validation_data = (x_test,y_test),verbose = 1,callbacks=[learning_rate_reduction])


print("\nTraining ✓\n")
# Out:
# Epoch 1/64
# 391/391 [==============================] - 74s 190ms/step - loss: 2.0011 - acc: 0.3368 - val_loss: 2.4096 - val_acc: 0.3924
# Epoch 2/64
# 391/391 [==============================] - 69s 177ms/step - loss: 1.2917 - acc: 0.5449 - val_loss: 1.1809 - val_acc: 0.6146
# Epoch 3/64
# 391/391 [==============================] - 69s 177ms/step - loss: 1.0294 - acc: 0.6453 - val_loss: 1.3396 - val_acc: 0.5823
# Epoch 4/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.8852 - acc: 0.6993 - val_loss: 0.9088 - val_acc: 0.7071
# Epoch 5/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.7814 - acc: 0.7360 - val_loss: 1.0730 - val_acc: 0.7125
# Epoch 6/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.6962 - acc: 0.7675 - val_loss: 0.8118 - val_acc: 0.7409
# Epoch 7/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.6267 - acc: 0.7933 - val_loss: 0.7504 - val_acc: 0.7840
# Epoch 8/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.5818 - acc: 0.8098 - val_loss: 0.8329 - val_acc: 0.7571
# Epoch 9/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.5351 - acc: 0.8247 - val_loss: 0.6634 - val_acc: 0.8002
# Epoch 10/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.4994 - acc: 0.8381 - val_loss: 0.7306 - val_acc: 0.8016
# Epoch 11/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.4758 - acc: 0.8459 - val_loss: 0.8129 - val_acc: 0.8059
# Epoch 12/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.4423 - acc: 0.8563 - val_loss: 0.6168 - val_acc: 0.8203
# Epoch 13/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.4215 - acc: 0.8634 - val_loss: 0.6647 - val_acc: 0.8119
# Epoch 14/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.3893 - acc: 0.8724 - val_loss: 0.7148 - val_acc: 0.7989
# Epoch 15/64
# 391/391 [==============================] - 70s 179ms/step - loss: 0.3718 - acc: 0.8793 - val_loss: 0.7454 - val_acc: 0.8032
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 16/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.2806 - acc: 0.9082 - val_loss: 0.5203 - val_acc: 0.8649
# Epoch 17/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.2567 - acc: 0.9165 - val_loss: 0.5765 - val_acc: 0.8521
# Epoch 18/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.2343 - acc: 0.9223 - val_loss: 0.5732 - val_acc: 0.8619
# Epoch 19/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.2253 - acc: 0.9265 - val_loss: 0.5191 - val_acc: 0.8743
# Epoch 20/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.2120 - acc: 0.9316 - val_loss: 0.5318 - val_acc: 0.8760
# Epoch 21/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.2006 - acc: 0.9355 - val_loss: 0.6980 - val_acc: 0.8423
# Epoch 22/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.1915 - acc: 0.9371 - val_loss: 0.6443 - val_acc: 0.8595
# Epoch 23/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.1910 - acc: 0.9384 - val_loss: 0.7071 - val_acc: 0.8512
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 24/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.1486 - acc: 0.9519 - val_loss: 0.6235 - val_acc: 0.8765
# Epoch 25/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.1332 - acc: 0.9567 - val_loss: 0.6441 - val_acc: 0.8748
# Epoch 26/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.1273 - acc: 0.9599 - val_loss: 0.6567 - val_acc: 0.8777
# Epoch 27/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.1265 - acc: 0.9607 - val_loss: 0.5825 - val_acc: 0.8851
# Epoch 28/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.1203 - acc: 0.9610 - val_loss: 0.5782 - val_acc: 0.8789
# Epoch 29/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.1184 - acc: 0.9629 - val_loss: 0.5616 - val_acc: 0.8773
# Epoch 30/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.1138 - acc: 0.9626 - val_loss: 0.7201 - val_acc: 0.8748
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 31/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0952 - acc: 0.9705 - val_loss: 0.6066 - val_acc: 0.8895
# Epoch 32/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0908 - acc: 0.9709 - val_loss: 0.6506 - val_acc: 0.8799
# Epoch 33/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0880 - acc: 0.9715 - val_loss: 0.5704 - val_acc: 0.8877
# Epoch 34/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0843 - acc: 0.9734 - val_loss: 0.6332 - val_acc: 0.8857
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 35/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0795 - acc: 0.9746 - val_loss: 0.5810 - val_acc: 0.8915
# Epoch 36/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0765 - acc: 0.9758 - val_loss: 0.5819 - val_acc: 0.8907
# Epoch 37/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0719 - acc: 0.9770 - val_loss: 0.6242 - val_acc: 0.8873
# Epoch 38/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0731 - acc: 0.9772 - val_loss: 0.6329 - val_acc: 0.8849
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 39/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.0693 - acc: 0.9779 - val_loss: 0.6054 - val_acc: 0.8923
# Epoch 40/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0763 - acc: 0.9757 - val_loss: 0.5963 - val_acc: 0.8916
# Epoch 41/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.0674 - acc: 0.9781 - val_loss: 0.6054 - val_acc: 0.8928
# Epoch 42/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.0690 - acc: 0.9779 - val_loss: 0.6249 - val_acc: 0.8908
# Epoch 43/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.0639 - acc: 0.9792 - val_loss: 0.6093 - val_acc: 0.8933
# Epoch 44/64
# 391/391 [==============================] - 69s 176ms/step - loss: 0.0663 - acc: 0.9787 - val_loss: 0.6485 - val_acc: 0.8892
# Epoch 45/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.0626 - acc: 0.9800 - val_loss: 0.6126 - val_acc: 0.8944
# Epoch 46/64
# 391/391 [==============================] - 69s 176ms/step - loss: 0.0655 - acc: 0.9789 - val_loss: 0.6077 - val_acc: 0.8935
# Epoch 47/64
# 391/391 [==============================] - 69s 176ms/step - loss: 0.0615 - acc: 0.9799 - val_loss: 0.6071 - val_acc: 0.8934
# Epoch 48/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.0653 - acc: 0.9791 - val_loss: 0.6487 - val_acc: 0.8910
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 49/64
# 391/391 [==============================] - 69s 176ms/step - loss: 0.0625 - acc: 0.9805 - val_loss: 0.6338 - val_acc: 0.8938
# Epoch 50/64
# 391/391 [==============================] - 72s 184ms/step - loss: 0.0586 - acc: 0.9816 - val_loss: 0.6359 - val_acc: 0.8944
# Epoch 51/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0621 - acc: 0.9805 - val_loss: 0.6212 - val_acc: 0.8951
# Epoch 52/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0587 - acc: 0.9810 - val_loss: 0.6257 - val_acc: 0.8937
# Epoch 53/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.0612 - acc: 0.9803 - val_loss: 0.6144 - val_acc: 0.8941
# Epoch 54/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0566 - acc: 0.9817 - val_loss: 0.6294 - val_acc: 0.8916
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 55/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0575 - acc: 0.9816 - val_loss: 0.6400 - val_acc: 0.8931
# Epoch 56/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0581 - acc: 0.9813 - val_loss: 0.6203 - val_acc: 0.8944
# Epoch 57/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0601 - acc: 0.9816 - val_loss: 0.6332 - val_acc: 0.8931
# Epoch 58/64
# 391/391 [==============================] - 70s 178ms/step - loss: 0.0585 - acc: 0.9807 - val_loss: 0.6228 - val_acc: 0.8944
# Epoch 59/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0580 - acc: 0.9814 - val_loss: 0.6204 - val_acc: 0.8938
# Epoch 60/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0552 - acc: 0.9820 - val_loss: 0.6207 - val_acc: 0.8941
# Epoch 61/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0600 - acc: 0.9808 - val_loss: 0.6292 - val_acc: 0.8930
# Epoch 62/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0589 - acc: 0.9815 - val_loss: 0.6370 - val_acc: 0.8922
# Epoch 63/64
# 391/391 [==============================] - 69s 178ms/step - loss: 0.0567 - acc: 0.9822 - val_loss: 0.6381 - val_acc: 0.8928
# Epoch 64/64
# 391/391 [==============================] - 69s 177ms/step - loss: 0.0574 - acc: 0.9814 - val_loss: 0.6411 - val_acc: 0.8925
#
# Training ✓

# %%
fig, ax = plt.subplots(2,1)

# Plot the accuracy curve for training and validation 
ax[0].plot(fitting_model.history['acc'], color='b', label="Training accuracy")
ax[0].plot(fitting_model.history['val_acc'], color='r',label="Validation accuracy")
legend = ax[0].legend(loc='best', shadow=True)

# Plot the loss curve for training and validation 
ax[1].plot(fitting_model.history['loss'], color='b', label="Training loss")
ax[1].plot(fitting_model.history['val_loss'], color='r', label="validation loss",axes =ax[1])
legend = ax[1].legend(loc='best', shadow=True)

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

print(check(scores[1]))
# Out:
# 10000/10000 [==============================] - 7s 742us/step
# Test loss: 0.6410590421043336
# Test accuracy: 0.8925
#
# Pass ✓✓✓
